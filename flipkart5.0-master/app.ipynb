# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.0 MB/s eta 0:00:00
# ...

# %%
import openai
import pandas as pd
from openai.embeddings_utils import get_embedding,cosine_similarity

# %% [markdown]
# # 1. Add your API key

# %%
api_key ="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"
openai.api_key = api_key

# %% [markdown]
# # 2. Create product data

# %%
import time
temp_product_data = [{'id': 1,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/4/j/s/free-ls-pinkberry-light-benaifer-fashion-unstitched-original-imagc97syewyypqw.jpeg?q=70',
  'brand': 'Divastri',
  'name': 'Woven Kanjivaram Pure Silk, Art Silk Saree',
  'price': '₹599',
  'gender': 'female',
  'Occasion': 'Casual, Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Kanjivaram',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Woven',
  'Fabric': 'Pure Silk, Art Silk'},
 {'id': 2,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/f/w/t/free-dt-paithani-art-silk-designer-bollywood-fashion-style-original-imagq779ed3grrhg.jpeg?q=70',
  'brand': 'Divastri',
  'name': 'Woven Kanjivaram Pure Silk Saree',
  'price': '₹649',
  'gender': 'female',
  'Occasion': 'Wedding & Festive, Party & Festive, Wedding, Casual',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Kanjivaram',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Woven',
  'Fabric': 'Pure Silk'},
 {'id': 3,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/l1pc3gw0/sari/k/g/q/free-bsp1625-banaras-silk-palace-unstitched-original-imagd7kkk39qhsrw.jpeg?q=70',
  'brand': 'Shradhha Fashion',
  'name': 'Embroidered Banarasi Satin Saree',
  'price': '₹565',
  'gender': 'female',
  'Occasion': 'Party & Festive, Wedding',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Banarasi',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Embroidered',
  'Fabric': 'Satin'},
 {'id': 4,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/x/k/3/free-red-saubhagyavati-saree-10-dailywear04-designer-stylist-original-imagg7hwpuudgmhq.jpeg?q=70',
  'brand': 'het designer studio',
  'name': 'Self Design, Paisley, Digital Print, Blocked Printed, W...',
  'price': '₹289',
  'gender': 'female',
  'Occasion': 'Casual, Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Banarasi',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Self Design, Paisley, Digital Print, Blocked Printed, Woven, Graphic Print, Checkered',
  'Fabric': 'Georgette, Art Silk'},
 {'id': 5,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/1/x/o/free-banarasi-avantika-fashion-unstitched-original-imagh576t2nhv8ey.jpeg?q=70',
  'brand': 'KAAYALI',
  'name': 'Woven Mysore Silk Blend, Pure Silk Saree',
  'price': '₹386',
  'gender': 'female',
  'Occasion': 'Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Mysore',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Woven',
  'Fabric': 'Silk Blend, Pure Silk'},
 {'id': 6,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/l5jxt3k0/sari/i/8/p/free-creeze-2-jay-krishna-garments-unstitched-original-imagg7nzcxrtxmes.jpeg?q=70',
  'brand': 'Hirpara Collection',
  'name': 'Solid/Plain Bollywood Satin Saree',
  'price': '₹649',
  'gender': 'female',
  'Occasion': 'Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bollywood',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Solid/Plain',
  'Fabric': 'Satin'},
 {'id': 7,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/b/g/p/free-silk-saree-pure-cotton-sarees-for-summer-daily-use-below-original-imagqrc8zf5rrufu.jpeg?q=70',
  'brand': 'MAANVIT',
  'name': 'Self Design Maheshwari Pure Silk, Art Silk Saree',
  'price': '₹741',
  'gender': 'female',
  'Occasion': 'Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Maheshwari',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Self Design',
  'Fabric': 'Pure Silk, Art Silk'},
 {'id': 8,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kynb6vk0/sari/j/r/t/free-gp-380-red-art-silk-designer-bollywood-fashion-style-litchi-original-imagatwfypgnt76v.jpeg?q=70',
  'brand': 'Keswi Fab',
  'name': 'Printed, Self Design, Paisley, Woven, Embellished, Appl...',
  'price': '₹489',
  'gender': 'female',
  'Occasion': 'Casual, Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Kanjivaram',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Printed, Self Design, Paisley, Woven, Embellished, Applique',
  'Fabric': 'Jacquard, Art Silk'},
 {'id': 9,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/l/r/s/free-av-75-aracruz-unstitched-original-imagbgdzex7hcj4t.jpeg?q=70',
  'brand': 'AVANTIKA FASHION',
  'name': 'Woven Kanjivaram Pure Silk, Art Silk Saree',
  'price': '₹459',
  'gender': 'female',
  'Occasion': 'Casual, Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Kanjivaram',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Woven',
  'Fabric': 'Pure Silk, Art Silk'},
 {'id': 10,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sari/o/e/e/free-ls-redbutta-maroon-benaifer-fashion-unstitched-original-imagjpp48hhh2xzk.jpeg?q=70',
  'brand': 'AVANTIKA FASHION',
  'name': 'Woven Kanjivaram Pure Silk, Art Silk Saree',
  'price': '₹459',
  'gender': 'female',
  'Occasion': 'Casual, Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Kanjivaram',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Woven',
  'Fabric': 'Pure Silk, Art Silk'},
{'id': 11,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/earring/u/h/e/na-morr-fashion-theme-original-imagnyd2zvhtsrwr.jpeg?q=70',
  'brand': 'Fashion Theme',
  'name': 'Fashion Theme Elegant Jhumki Different Design Of Peacoc...',
  'price': '₹350',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Religious, Love',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'White',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Crystal, Stone',
  'Gemstone': 'Beads, Crystal, Pearl',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 12,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/earring/r/b/n/na-earings-fashion-theme-original-imagzmkhezp8hkza.jpeg?q=70',
  'brand': 'Fashion Theme',
  'name': 'Jhumka Stylish Trendy Earring for Woman & Girls Pink Co...',
  'price': '₹177',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Workwear, Everyday, Love, Religious',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'Purple',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Brass',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 13,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kll7bm80/earring/i/l/u/gold-jhumki-me159-meenaz-original-imagyzhtthh34gyt.jpeg?q=70',
  'brand': 'MEENAZ',
  'name': '1 one gram gold South Indian Temple jewellery set 18k B...',
  'price': '₹238',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Love, Religious, Everyday, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'Gold',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Brass, Copper, Metal, Alloy, Enamel, Crystal, Stone',
  'Gemstone': 'Ruby',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy, Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 14,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kll7bm80/earring/d/d/d/gold-jhumki-me181-meenaz-original-imagyzqbtnhzngtn.jpeg?q=70',
  'brand': 'MEENAZ',
  'name': '1 one gram gold South Indian Temple jewellery set 18k B...',
  'price': '₹269',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Love, Religious, Everyday, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'Yellow, Gold, Red, Green',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Brass, Copper, Metal, Alloy, Enamel, Crystal, Stone',
  'Gemstone': 'Diamond, Cubic Zirconia',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy, Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 15,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kgiaykw0/earring/u/t/k/dj-584-divastri-original-imafwqeyzyknvhgy.jpeg?q=70',
  'brand': 'Divastri',
  'name': 'Traditional jhumka Jhumkas 1 gram gold wedding bridal S...',
  'price': '₹269',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Workwear, Everyday, Religious, Love',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring, Earring Set, Drops & Danglers',
  'Color': 'Yellow, Gold, Pink',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Brass, Copper',
  'Gemstone': 'Ruby, Diamond',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 16,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kj7gwi80-0/earring/5/2/e/gold-jhumki-d117-divastri-original-imafyu2a7ukq7rxe.jpeg?q=70',
  'brand': 'Divastri',
  'name': 'Divastri Traditional South Indian Temple Jewellery Scre...',
  'price': '₹400',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Love, Workwear, Everyday, Religious',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Earring Set, Jhumki Earring',
  'Color': 'Yellow, Gold',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Copper, Brass, Metal, Alloy',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy, Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 17,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/earring/e/5/2/na-meenakari-dome-shape-jhumka-earrings-with-lotus-engraved-and-original-imagq8b9sf6eg7fb.jpeg?q=70',
  'brand': "Nilu's Collection",
  'name': 'Meenakari Dome Shape Jhumka Earrings with Lotus engrave...',
  'price': '₹499',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Religious, Love',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'Blue',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Brass',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 18,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/earring/q/2/t/na-pearl-earring-fashion-theme-original-imagr937m8sejsfe.jpeg?q=70',
  'brand': 'Fashion Theme',
  'name': 'Trendy Jhumka Earring (Red & Multicolor) Combo Pack of ...',
  'price': '₹399',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Everyday, Love, Religious, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Earring Set',
  'Color': 'Multicolor, Silver',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Alloy',
  'Gemstone': 'Crystal, Beads, Pearl',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 19,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kj7gwi80-0/earring/l/p/q/gold-jhumki-d116-divastri-original-imafyu27vh9yrf85.jpeg?q=70',
  'brand': 'Divastri',
  'name': 'Divastri Traditional South Indian Temple Jewellery Scre...',
  'price': '₹400',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Love, Workwear, Everyday, Religious',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Earring Set, Jhumki Earring',
  'Color': 'Yellow, Gold',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Copper, Brass, Metal, Alloy',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy, Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 20,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kll7bm80/earring/s/k/9/gold-jhumki-me166-meenaz-original-imagyzheydhz5hvq.jpeg?q=70',
  'brand': 'MEENAZ',
  'name': '1 one gram gold South Indian Temple jewellery set 18k B...',
  'price': '₹350',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Love, Religious, Everyday, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'Gold',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Stone',
  'Gemstone': 'Ruby',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
{'id': 21,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/bangle-bracelet-armlet/p/j/3/free-free-na-2-sgj421-neerajyoti-original-imagrzh4znkajpx5.jpeg?q=70',
  'brand': 'Neerajyoti',
  'name': 'Crystal Crystal Bracelet Set',
  'price': '₹214',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bracelet Set',
  'Color': 'White, Black',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Crystal',
  'Gemstone': 'Crystal',
  'Diameter': 'free inch',
  'Bangle Size': 'Free',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 22,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kmkxbww0/bangle-bracelet-armlet/k/b/0/free-8-3-king-black-blue-brown-happy-khajana-original-imagfgg8z2ujjy4j.jpeg?q=70',
  'brand': 'Happy Khajana',
  'name': 'Metal Crystal Black Silver Bracelet Set',
  'price': '₹184',
  'gender': 'female',
  'Occasion': 'Everyday',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bracelet Set',
  'Color': 'Black, Blue, Brown',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Metal',
  'Gemstone': 'Crystal',
  'Diameter': '8 inch',
  'Bangle Size': 'Free',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 23,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kf5pzm80/bangle-bracelet-armlet/4/e/k/2-8-2-8-16-gk20-lily-zulka-get-your-traditions-original-imafvzkdqm5q3tth.jpeg?q=70',
  'brand': 'Zulka Get Your Traditions',
  'name': 'Glass Bangle Set',
  'price': '₹749',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Multicolor',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Glass',
  'Gemstone': 'NULL',
  'Diameter': '2.8 inch',
  'Bangle Size': '2-8',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 24,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/jndhrbk0/bangle-bracelet-armlet/s/h/a/2-8-24-g460-nmii-original-imafa2tzqefg2kf9.jpeg?q=70',
  'brand': 'NMII',
  'name': 'Glass Bangle Set',
  'price': '₹500',
  'gender': 'female',
  'Occasion': 'Everyday, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Multicolor',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Glass',
  'Gemstone': 'NULL',
  'Diameter': '2.4 inch',
  'Bangle Size': '2-4',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 25,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/k3j1z0w0/bangle-bracelet-armlet/m/r/n/2-8-2-n4-po2-zulka-get-your-traditions-original-imafmmzc85xqhpfz.jpeg?q=70',
  'brand': 'Zulka Get Your Traditions',
  'name': 'Glass Zircon Bangle Set',
  'price': '₹749',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Brown',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Glass',
  'Gemstone': 'Zircon',
  'Diameter': '2.8 inch',
  'Bangle Size': '2.8',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 26,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/jjylw280/bangle-bracelet-armlet/4/y/z/2-6-12-g412-p-golden-nmii-original-imaf7e32vk8yncnt.jpeg?q=70',
  'brand': 'NMII',
  'name': 'Metal Bangle Set',
  'price': '₹349',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Gold',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Metal',
  'Gemstone': 'NULL',
  'Diameter': '2.4 inch',
  'Bangle Size': '2-4',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 27,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/bangle-bracelet-armlet/7/3/w/2-8-2-8-na-102-kiaancreation-original-imags5ghzqwrnc4r.jpeg?q=70',
  'brand': 'KIAANCREATION',
  'name': 'Plastic Bangle Set',
  'price': '₹199',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Yellow',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Plastic',
  'Gemstone': 'NULL',
  'Diameter': '2-4 inch',
  'Bangle Size': '2-4',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 28,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/bangle-bracelet-armlet/v/j/x/free-free-size-na-2-bb4-neerajyoti-original-imagrm4h6ht3fhry.jpeg?q=70',
  'brand': 'Neerajyoti',
  'name': 'Crystal Bracelet Set',
  'price': '₹214',
  'gender': 'female',
  'Occasion': 'Love, Religious, Everyday, Workwear, Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bracelet Set',
  'Color': 'White, Black',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Crystal',
  'Gemstone': 'NULL',
  'Diameter': 'Free Size',
  'Bangle Size': 'Free',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 29,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/jvy4vbk0/bangle-bracelet-armlet/r/3/g/2-6-32-shisa-k5-zulka-get-your-traditions-original-imafgqwsgsfteph2.jpeg?q=70',
  'brand': 'Zulka Get Your Traditions',
  'name': 'Plastic Zircon Bangle Set',
  'price': '₹809',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Multicolor',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Plastic',
  'Gemstone': 'Zircon',
  'Diameter': '2.8 inch',
  'Bangle Size': '2-8',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 30,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/jvo4scw0/bangle-bracelet-armlet/d/n/z/2-8-28-g435-peach-gajri-nmii-original-imaf7fg7zfpuagnf.jpeg?q=70',
  'brand': 'NMII',
  'name': 'Metal, Fabric Zircon Bangle Set',
  'price': '₹500',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Religious, Love, Everyday, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Beige',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Metal, Fabric',
  'Gemstone': 'Zircon',
  'Diameter': '2.4 inch',
  'Bangle Size': '2-4',
  'Collection': 'NULL',
  'Design': 'NMII Non-Precious Metal Base Metal with Silk thread Or Zircon Gemstone and Linked with Ball Chain Glossy Finished Bangle Set For Women and Girls',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
{'id': 31,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/slipper-flip-flop/p/x/y/5-new-aerosoft-footwear-red-original-imagscb9y5ztvstm.jpeg?q=70',
  'brand': 'Aerosoft Footwear',
  'name': 'Slippers',
  'price': '₹179',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'NULL',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 32,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sandal/t/6/o/8-250-red-eva-deals4you-red-original-imagrnpyj68vgmee.jpeg?q=70',
  'brand': 'Deals4you',
  'name': 'Women Red Flats Sandal',
  'price': '₹499',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Flats',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Sandal',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 33,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sandal/z/v/n/4-2025-4-albela-red-original-imagpr2xffjdgpyj.jpeg?q=70',
  'brand': 'albela',
  'name': 'Women Red Wedges Sandal',
  'price': '₹469',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Wedges',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 34,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kdrpksw0-0/sandal/e/c/a/bt-1021-7-shoenstring-red-original-imafuhhgcyxvzjjy.jpeg?q=70',
  'brand': 'Bootco',
  'name': 'Women Red Flats Sandal',
  'price': '₹295',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Flats',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Slip-on',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 35,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sandal/q/f/y/-original-imaggnu4zrbcmfnz.jpeg?q=70',
  'brand': 'AMAZING TRADERS',
  'name': 'Women Red Flats Sandal',
  'price': '₹209',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Flats',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Sandal',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 36,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sandal/d/e/2/7-517-urfi-shozie-red-black-original-imags9jpzqprftjh.jpeg?q=70',
  'brand': 'Shozie',
  'name': 'Women Red Flats Sandal',
  'price': '₹299',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Flats',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Sandal',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 37,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/l59xq4w0/sandal/r/2/a/3-bt-1021-3-shoenstring-red-original-imagfzp7tjxhzpke.jpeg?q=70',
  'brand': 'Jogvy',
  'name': 'Women Red Flats Sandal',
  'price': '₹391',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Flats',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Ethnic Sandal(Chappal)',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 38,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/slipper-flip-flop/r/t/p/-original-imags4f9xzyyhwrf.jpeg?q=70',
  'brand': 'RED TAPE',
  'name': 'Flip Flops',
  'price': '₹332',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'NULL',
  'Color': 'Pink',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 39,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sandal/t/l/p/-original-imaghxfek2zn55zx.jpeg?q=70',
  'brand': 'Nyle Collection',
  'name': 'Women Red Heels Sandal',
  'price': '₹236',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Heels',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
 {'id': 40,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/sandal/y/0/a/3-617-red-3-shozie-red-original-imagqy2haj347gkx.jpeg?q=70',
  'brand': 'Shozie',
  'name': 'Women Red Flats Sandal',
  'price': '₹299',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Flats',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Sandal',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'}]

product_data_df = pd.DataFrame()  # Initialize an empty DataFrame

for i in range(0, len(temp_product_data), 3):
    temp = temp_product_data[i:i + 3]  # Extract a group of three items
    temp_product_data_df = pd.DataFrame(temp)

    # Combine columns and add to DataFrame
    temp_product_data_df['combined'] = temp_product_data_df.apply(
        lambda row: f"{row['id']}, {row['category']}, {row['url']},{row['brand']}, {row['name']}, {row['price']},{row['gender']},{row['Occasion']},{row['Display Type']}, {row['Strap Color']}, {row['Type']},{row['Color']}, {row['Outer material']}, {row['Type for Flats']},{row['Base Material']},{row['Gemstone']},{row['Diameter']}, {row['Bangle Size']}, {row['Collection']},{row['Design']},{row['Pattern']},{row['Fabric']}", axis=1
    )

    # Assuming you have the 'get_embedding' function implemented
    temp_product_data_df['text_embedding'] = temp_product_data_df.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))

    # Concatenate the current group's DataFrame to the main DataFrame
    product_data_df = pd.concat([product_data_df, temp_product_data_df])

    # Increment i by 3 to move to the next group
    i += 3
    time.sleep(60)

print(product_data_df)
# Out:
#    id  category                                                url  \
# 0   1     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   2     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   3     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   4     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   5     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   6     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   7     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   8     saree  https://rukminim2.flixcart.com/image/612/612/k...
# 2   9     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 0  10     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1  11    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 2  12    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 0  13    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# ...

# %% [markdown]
# # 3. Add product data to dataframe

# %%
product_data_df = pd.DataFrame(product_data_df)
product_data_df
# Out:
#    id  category                                                url  \
# 0   1     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   2     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   3     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   4     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   5     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   6     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   7     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   8     saree  https://rukminim2.flixcart.com/image/612/612/k...
# 2   9     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 0  10     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1  11    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 2  12    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 0  13    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# ...

# %% [markdown]
# # 4. Create column with combined data

# %%
product_data_df['combined'] = product_data_df.apply( lambda row: f"{row['id']}, {row['category']}, {row['url']},{row['brand']}, {row['name']}, {row['price']},{row['gender']},{row['Occasion']},{row['Display Type']}, {row['Strap Color']}, {row['Type']},{row['Color']}, {row['Outer material']}, {row['Type for Flats']},{row['Base Material']},{row['Gemstone']},{row['Diameter']}, {row['Bangle Size']}, {row['Collection']},{row['Design']},{row['Pattern']},{row['Fabric']}", axis=1)
product_data_df
# Out:
#    id  category                                                url  \
# 0   1     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   2     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   3     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   4     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   5     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   6     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   7     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   8     saree  https://rukminim2.flixcart.com/image/612/612/k...
# 2   9     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 0  10     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1  11    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 2  12    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 0  13    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# ...

# %%
product_data_df
# Out:
#    id  category                                                url  \
# 0   1     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   2     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   3     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   4     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   5     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2   6     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 0   7     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   8     saree  https://rukminim2.flixcart.com/image/612/612/k...
# 2   9     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 0  10     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1  11    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 2  12    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 0  13    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# ...

# %% [markdown]
# # 5. Create embeddings for combined product data

# %%
product_data_df.to_csv('embeddings.csv', index=False)

# %%
# product_data_df['text_embedding'] = product_data_df.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
# product_data_df

# %% [markdown]
# # 6. Create customer profile data

# %%
customer_order_data = [{'id': 37,
  'category': 'footwear',
  'url': 'https://rukminim2.flixcart.com/image/832/832/xif0q/sandal/3/r/n/-original-imaggewzwavmfqtn.jpeg?q=70',
  'brand': 'Aliz Footwear ',
  'name': 'Women Gold Heels Sandal',
  'price': '₹391',
  'gender': 'female',
  'Occasion': 'NULL',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Heels',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'Ethnic Sandal(Chappal)',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
    {'id': 1,
  'category': 'saree',
  'url': 'https://rukminim2.flixcart.com/image/832/832/xif0q/sari/h/9/m/free-ls-ramleela-kanjieevaram-soft-lichi-silk-zari-woven-saree-original-imagmcdezekjzhsf.jpeg?q=70',
  'brand': 'DP Art',
  'name': 'Woven Kanjivaram Pure Silk, Art Silk Saree  (Purple)',
  'price': '₹599',
  'gender': 'female',
  'Occasion': 'Party & Festive, Wedding, Wedding & Festive',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Kanjivaram',
  'Color': 'NULL',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'NULL',
  'Gemstone': 'NULL',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'Woven',
  'Fabric': 'Pure Silk, Art Silk'},
  {'id': 27,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/bangle-bracelet-armlet/7/3/w/2-8-2-8-na-102-kiaancreation-original-imags5ghzqwrnc4r.jpeg?q=70',
  'brand': 'AFAST',
  'name': 'Glass Bangle Set  (Pack of 20)',
  'price': '282',
  'gender': 'female',
  'Occasion': 'Everyday, Love, Religious, Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Glass',
  'Gemstone': 'NULL',
  'Diameter': '2-6 inch',
  'Bangle Size': '2-6',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},
  {'id': 14,
  'category': 'jhumka',
  'url': 'https://rukminim2.flixcart.com/image/612/612/kll7bm80/earring/d/d/d/gold-jhumki-me181-meenaz-original-imagyzqbtnhzngtn.jpeg?q=70',
  'brand': 'Divastri',
  'name': 'Bridal Wedding Traditional Gold Pearl Peacock Kundan Jhumkas/ Jhumka/ Jhumki Earrings For Women Girls Pearl Copper, Metal Jhumki Earring',
  'price': '₹259',
  'gender': 'female',
  'Occasion': 'Wedding & Engagement, Love, Religious, Everyday, Workwear',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Jhumki Earring',
  'Color': 'Gold,Black',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Copper, Metal',
  'Gemstone': 'Pearl',
  'Diameter': 'NULL',
  'Bangle Size': 'NULL',
  'Collection': 'Ethnic',
  'Design': 'Heavy, Statement, Minimal',
  'Pattern': 'NULL',
  'Fabric': 'NULL'}
]

# %%
{'id': 27,
  'category': 'bangles',
  'url': 'https://rukminim2.flixcart.com/image/612/612/xif0q/bangle-bracelet-armlet/7/3/w/2-8-2-8-na-102-kiaancreation-original-imags5ghzqwrnc4r.jpeg?q=70',
  'brand': 'AFAST',
  'name': 'Glass Bangle Set  (Pack of 20)',
  'price': '282',
  'gender': 'female',
  'Occasion': 'Everyday, Love, Religious, Wedding & Engagement',
  'Display Type': 'NULL',
  'Strap Color': 'NULL',
  'Type': 'Bangle Set',
  'Color': 'Red',
  'Outer material': 'NULL',
  'Type for Flats': 'NULL',
  'Base Material': 'Glass',
  'Gemstone': 'NULL',
  'Diameter': '2-6 inch',
  'Bangle Size': '2-6',
  'Collection': 'NULL',
  'Design': 'NULL',
  'Pattern': 'NULL',
  'Fabric': 'NULL'},

# %%
# {
#     "prod_id": 5,
#     "prod": "concealer",
#     "brand":"chanel",
#     "description": "medium coverage"
# },
#  {
#     "prod_id": 9,
#     "prod": "makeup sponge",
#     "brand":"Sephora",
#     "description": "super-soft, exclusive, latex-free foam"
# }

# %% [markdown]
# # 7. Add customer profile data to dataframe

# %%
customer_order_df = pd.DataFrame(customer_order_data)
customer_order_df
# Out:
#    id  category                                                url  \
# 0  37  footwear  https://rukminim2.flixcart.com/image/832/832/x...
# 1   1     saree  https://rukminim2.flixcart.com/image/832/832/x...
# 2  14    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
#
#             brand                                               name price  \
# 0  Aliz Footwear                             Women Gold Heels Sandal  ₹391
# 1          DP Art  Woven Kanjivaram Pure Silk, Art Silk Saree  (P...  ₹599
# 2        Divastri  Bridal Wedding Traditional Gold Pearl Peacock ...  ₹259
#
#    gender                                           Occasion Display Type  \
# 0  female                                               NULL         NULL
# 1  female        Party & Festive, Wedding, Wedding & Festive         NULL
# 2  female  Wedding & Engagement, Love, Religious, Everyda...         NULL
#
#   Strap Color  ... Outer material          Type for Flats  Base Material  \
# ...

# %% [markdown]
# # 8. Create combined column for customer profile

# %%
customer_order_df['combined'] = customer_order_df.apply(lambda row: f"{row['id']}, {row['category']}, {row['url']},{row['brand']}, {row['name']}, {row['price']},{row['gender']},{row['Occasion']},{row['Display Type']}, {row['Strap Color']}, {row['Type']},{row['Color']}, {row['Outer material']}, {row['Type for Flats']},{row['Base Material']},{row['Gemstone']},{row['Diameter']}, {row['Bangle Size']}, {row['Collection']},{row['Design']},{row['Pattern']},{row['Fabric']}", axis=1)
customer_order_df
# Out:
#    id  category                                                url  \
# 0  37  footwear  https://rukminim2.flixcart.com/image/832/832/x...
# 1   1     saree  https://rukminim2.flixcart.com/image/832/832/x...
# 2  14    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
#
#             brand                                               name price  \
# 0  Aliz Footwear                             Women Gold Heels Sandal  ₹391
# 1          DP Art  Woven Kanjivaram Pure Silk, Art Silk Saree  (P...  ₹599
# 2        Divastri  Bridal Wedding Traditional Gold Pearl Peacock ...  ₹259
#
#    gender                                           Occasion Display Type  \
# 0  female                                               NULL         NULL
# 1  female        Party & Festive, Wedding, Wedding & Festive         NULL
# 2  female  Wedding & Engagement, Love, Religious, Everyda...         NULL
#
#   Strap Color  ...          Type for Flats  Base Material Gemstone Diameter  \
# ...

# %% [markdown]
# # 9. Create customer profile data embeddings

# %%
customer_order_df['text_embedding'] = customer_order_df.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
customer_order_df.to_csv('customer_dataset.csv')
customer_order_df
# Out:
#    id  category                                                url  \
# 0  37  footwear  https://rukminim2.flixcart.com/image/832/832/x...
# 1   1     saree  https://rukminim2.flixcart.com/image/832/832/x...
# 2  14    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
#
#             brand                                               name price  \
# 0  Aliz Footwear                             Women Gold Heels Sandal  ₹391
# 1          DP Art  Woven Kanjivaram Pure Silk, Art Silk Saree  (P...  ₹599
# 2        Divastri  Bridal Wedding Traditional Gold Pearl Peacock ...  ₹259
#
#    gender                                           Occasion Display Type  \
# 0  female                                               NULL         NULL
# 1  female        Party & Festive, Wedding, Wedding & Festive         NULL
# 2  female  Wedding & Engagement, Love, Religious, Everyda...         NULL
#
#   Strap Color  ...  Base Material Gemstone Diameter Bangle Size Collection  \
# ...

# %% [markdown]
# # 10. Create embeddings for input question

# %%
customer_input = "I want outfit for wedding"
customer_input1="convert the products list into json file"
customer_input2= "I like the saree, but the jhumkas are boring, give me something else"

# %%
response = openai.Embedding.create(
    input=customer_input,
    model="text-embedding-ada-002"
)
embeddings_customer_question = response['data'][0]['embedding']

# %%
response = openai.Embedding.create(
    input=customer_input1,
    model="text-embedding-ada-002"
)
embeddings_customer_question = response['data'][0]['embedding']

# %%
response = openai.Embedding.create(
    input=customer_input2,
    model="text-embedding-ada-002"
)
embeddings_customer_question = response['data'][0]['embedding']

# %% [markdown]
# # 11. Get similarities for purchase history

# %%
customer_order_df['search_purchase_history'] = customer_order_df.text_embedding.apply(lambda x: cosine_similarity(x, embeddings_customer_question))
customer_order_df = customer_order_df.sort_values('search_purchase_history', ascending=False)
customer_order_df
# Out:
#    id  category                                                url  \
# 2  14    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 1   1     saree  https://rukminim2.flixcart.com/image/832/832/x...
# 0  37  footwear  https://rukminim2.flixcart.com/image/832/832/x...
#
#             brand                                               name price  \
# 2        Divastri  Bridal Wedding Traditional Gold Pearl Peacock ...  ₹259
# 1          DP Art  Woven Kanjivaram Pure Silk, Art Silk Saree  (P...  ₹599
# 0  Aliz Footwear                             Women Gold Heels Sandal  ₹391
#
#    gender                                           Occasion Display Type  \
# 2  female  Wedding & Engagement, Love, Religious, Everyda...         NULL
# 1  female        Party & Festive, Wedding, Wedding & Festive         NULL
# 0  female                                               NULL         NULL
#
#   Strap Color  ... Gemstone Diameter Bangle Size Collection  \
# ...

# %% [markdown]
# # 12. Save top 3 similarities for purchase history

# %%
top_3_purchases_df = customer_order_df.head(3)
top_3_purchases_df.to_csv('customer_order.csv')
top_3_purchases_df
# Out:
#    id  category                                                url  \
# 2  14    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 1   1     saree  https://rukminim2.flixcart.com/image/832/832/x...
# 0  37  footwear  https://rukminim2.flixcart.com/image/832/832/x...
#
#             brand                                               name price  \
# 2        Divastri  Bridal Wedding Traditional Gold Pearl Peacock ...  ₹259
# 1          DP Art  Woven Kanjivaram Pure Silk, Art Silk Saree  (P...  ₹599
# 0  Aliz Footwear                             Women Gold Heels Sandal  ₹391
#
#    gender                                           Occasion Display Type  \
# 2  female  Wedding & Engagement, Love, Religious, Everyda...         NULL
# 1  female        Party & Festive, Wedding, Wedding & Festive         NULL
# 0  female                                               NULL         NULL
#
#   Strap Color  ... Gemstone Diameter Bangle Size Collection  \
# ...

# %% [markdown]
# # 13. Get similarities for products

# %%
product_data_df['search_products'] = product_data_df.text_embedding.apply(lambda x: cosine_similarity(x, embeddings_customer_question))
product_data_df = product_data_df.sort_values('search_products', ascending=False)
product_data_df
# Out:
#    id  category                                                url  \
# 2   6     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 1   8     saree  https://rukminim2.flixcart.com/image/612/612/k...
# 0   4     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1  11    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 2   3     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 1   5     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2  18    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 0  10     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   2     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 0  19    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 0  16    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 2  15    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 2  12    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# ...

# %% [markdown]
# # 14. Save top 3 similarities for products

# %%
# category=['saree','bangles','footwear','jhumka']
# product_list=[]
# for index,row in product_data_df.iterrows():
#   if(row['category'] in category):
#     product_list.append(row)
#     category.remove(row['category'])
# print(product_list)

# %%
# product_list=pd.DataFrame(product_list)
# # print(product_list)
# product_list

# %%
top_3_purchases_df = customer_order_df.head(5)
top_3_purchases_df
# Out:
#    id  category                                                url  \
# 2  14    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 1   1     saree  https://rukminim2.flixcart.com/image/832/832/x...
# 0  37  footwear  https://rukminim2.flixcart.com/image/832/832/x...
#
#             brand                                               name price  \
# 2        Divastri  Bridal Wedding Traditional Gold Pearl Peacock ...  ₹259
# 1          DP Art  Woven Kanjivaram Pure Silk, Art Silk Saree  (P...  ₹599
# 0  Aliz Footwear                             Women Gold Heels Sandal  ₹391
#
#    gender                                           Occasion Display Type  \
# 2  female  Wedding & Engagement, Love, Religious, Everyda...         NULL
# 1  female        Party & Festive, Wedding, Wedding & Festive         NULL
# 0  female                                               NULL         NULL
#
#   Strap Color  ... Gemstone Diameter Bangle Size Collection  \
# ...

# %%
top_3_products_df = product_data_df.head(40)
top_3_products_df
# Out:
#    id  category                                                url  \
# 2   6     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 1   8     saree  https://rukminim2.flixcart.com/image/612/612/k...
# 0   4     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1  11    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 2   3     saree  https://rukminim2.flixcart.com/image/612/612/l...
# 1   5     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 2  18    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# 0  10     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 1   2     saree  https://rukminim2.flixcart.com/image/612/612/x...
# 0  19    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 0  16    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 2  15    jhumka  https://rukminim2.flixcart.com/image/612/612/k...
# 2  12    jhumka  https://rukminim2.flixcart.com/image/612/612/x...
# ...

# %% [markdown]
# # 15. Create prompt

# %%
message_objects = []
message_objects.append({"role":"system", "content":"You're a chatbot helping customers with otfit related questions and helping them with product recommendations full otfit items such as Saree,bangles,jhumka,bangles etc "})
message_objects1 = []
message_objects1.append({"role":"system", "content":"You're a chatbot who converts the given list into JSON format"})

# %%
# Append the customer messagae
message_objects.append({"role":"user", "content": customer_input})
message_objects1.append({"role":"user", "content": customer_input1})

# %%
# Create previously purchased input
prev_purchases = ". ".join([f"{row['combined']}" for index, row in top_3_purchases_df.iterrows()])
prev_purchases
# Out:
# '37, footwear, https://rukminim2.flixcart.com/image/832/832/xif0q/sandal/3/r/n/-original-imaggewzwavmfqtn.jpeg?q=70,Aliz Footwear , Women Gold Heels Sandal, ₹391,female,NULL,NULL, NULL, Heels,Red, NULL, Ethnic Sandal(Chappal),NULL,NULL,NULL, NULL, NULL,NULL,NULL,NULL. 1, saree, https://rukminim2.flixcart.com/image/832/832/xif0q/sari/h/9/m/free-ls-ramleela-kanjieevaram-soft-lichi-silk-zari-woven-saree-original-imagmcdezekjzhsf.jpeg?q=70,DP Art, Woven Kanjivaram Pure Silk, Art Silk Saree  (Purple), ₹599,female,Party & Festive, Wedding, Wedding & Festive,NULL, NULL, Kanjivaram,NULL, NULL, NULL,NULL,NULL,NULL, NULL, NULL,NULL,Woven,Pure Silk, Art Silk. 14, jhumka, https://rukminim2.flixcart.com/image/612/612/kll7bm80/earring/d/d/d/gold-jhumki-me181-meenaz-original-imagyzqbtnhzngtn.jpeg?q=70,Divastri, Bridal Wedding Traditional Gold Pearl Peacock Kundan Jhumkas/ Jhumka/ Jhumki Earrings For Women Girls Pearl Copper, Metal Jhumki Earring, ₹259,female,Wedding & Engagement, Love, Religious, E
# ...

# %%
# Append prev relevant purchase
message_objects.append({"role":"user", "content": f"Here're my latest product orders: {prev_purchases}"})
message_objects.append({"role":"user", "content": f"Please give recomend me one product from each category, the categories are given to you"})
message_objects.append({"role":"user", "content": f"Please give me a detailed explanation of your recommendations"})
message_objects.append({"role":"user", "content": "Please be friendly and talk to me like a person, don't just give me a list of recommendations"})

# %%
# Create list of 3 products to recommend
products_list = []
bre_l=[]
for index, row in top_3_products_df.iterrows():
    brand_dict = {'role': "assistant", "content":  f"{row['id']}, {row['category']},{row['brand']}, {row['name']}, {row['price']},{row['gender']},{row['Occasion']},{row['Display Type']}, {row['Strap Color']}, {row['Type']},{row['Color']}, {row['Outer material']}, {row['Type for Flats']},{row['Base Material']},{row['Gemstone']},{row['Diameter']}, {row['Bangle Size']}, {row['Collection']},{row['Design']},{row['Pattern']},{row['Fabric']},{row['url']}"}
    products_list.append(brand_dict)
    #bre={row: f"{row['url']}, {row['brand']}, {row['name']},{row['price']}, {row['Ocassion']}, {row['Color']},{row['Pattern']},{row['Fabric']},{row['Occasion']}"}
    #bre_l.append(bre)
products_list
# Out:
# [{'role': 'assistant',
#   'content': '31, footwear,Aerosoft Footwear, Slippers, ₹179,female,NULL,NULL, NULL, NULL,Red, NULL, NULL,NULL,NULL,NULL, NULL, NULL,NULL,NULL,NULL,https://rukminim2.flixcart.com/image/612/612/xif0q/slipper-flip-flop/p/x/y/5-new-aerosoft-footwear-red-original-imagscb9y5ztvstm.jpeg?q=70'},
#  {'role': 'assistant',
#   'content': '10, saree,AVANTIKA FASHION, Woven Kanjivaram Pure Silk, Art Silk Saree, ₹459,female,Casual, Party & Festive, Wedding, Wedding & Festive,NULL, NULL, Kanjivaram,NULL, NULL, NULL,NULL,NULL,NULL, NULL, NULL,NULL,Woven,Pure Silk, Art Silk,https://rukminim2.flixcart.com/image/612/612/xif0q/sari/o/e/e/free-ls-redbutta-maroon-benaifer-fashion-unstitched-original-imagjpp48hhh2xzk.jpeg?q=70'},
#  {'role': 'assistant',
# ...

# %%
# Append found products
message_objects.append({"role": "assistant", "content": f"I found these  products I would recommend"})
# message_objects.extend(products_list)
# message_objects.append({"role": "assistant", "content":"Here's my summarized recommendation of products, and why it would suit you:"})
# message_objects.extend
message_objects1.extend(products_list)
message_objects1.extend
# Out:
# <function list.extend(iterable, /)>

# %% [markdown]
# # 16. Call ChatGPT API

# %%
# completion = openai.ChatCompletion.create(
#   model="gpt-3.5-turbo",
#   messages=message_objects1
# )

# print(completion.choices[0].message['content'])

# %%
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=message_objects
)

print(completion.choices[0].message['content'])
# Out:
# Here are my recommendations for a wedding outfit:
#
# 1. Saree:
#    - Product: Woven Kanjivaram Pure Silk, Art Silk Saree (Purple) by DP Art
#    - Price: ₹599
#    - Description: This beautiful purple saree with intricate woven design is perfect for a wedding. The Kanjivaram silk fabric adds a touch of elegance and the vibrant color will make you stand out.
#
# 2. Footwear:
#    - Product: Women Gold Heels Sandal by Aliz Footwear
#    - Price: ₹391
#    - Description: These gold heels sandals are the perfect choice to complement your wedding outfit. The stylish design and comfortable fit will ensure you can dance the night away without any discomfort.
#
# 3. Jhumka Earrings:
#    - Product: Bridal Wedding Traditional Gold Pearl Peacock Kundan Jhumkas by Divastri
#    - Price: ₹259
# ...

# %%
completion1 = openai.ChatCompletion.create(
   model="gpt-3.5-turbo",
   messages=message_objects1
)

print(completion1.choices[0].message['content'])
# Out:
# {
#   "products": [
#     {
#       "id": 31,
#       "category": "footwear",
#       "brand": "Aerosoft Footwear",
#       "type": "Slippers",
#       "price": "₹179",
#       "gender": "female",
#       "occasion": null,
#       "style": null,
#       "size": null,
#       "color": "Red",
#       "material": null,
#       "pattern": null,
#       "description": null,
#       "rating": null,
#       "reviews": null,
#       "availability": null,
#       "discount": null,
#       "additionalInfo": null,
#       "imageURL": "https://rukminim2.flixcart.com/image/612/612/xif0q/slipper-flip-flop/p/x/y/5-new-aerosoft-footwear-red-original-imagscb9y5ztvstm.jpeg?q=70"
#     },
#     {
#       "id": 10,
#       "category": "saree",
#       "brand": "AVANTIKA FASHION",
#       "type": "Woven Kanjivaram Pure Silk, Art Silk Saree",
#       "price": "₹459",
#       "gender": "female",
#       "occasion": "Casual, Party & Festive, Wedding, Wedding & Festive",
#       "style": null,
# ...
